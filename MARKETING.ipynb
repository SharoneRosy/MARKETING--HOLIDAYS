# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1= pd.read_csv('Ecommerce_Data.csv')
df1.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                        Description  \
# 0      439570    574477     22591  CARDHOLDER GINGHAM CHRISTMAS TREE
# 1      387281    570275     23541         WALL ART CLASSIC PUDDINGS
# 2      337863    566482     22508           DOORSTOP RETROSPOT HEART
# 3       57628    541215     22662        LUNCH BAG DOLLY GIRL DESIGN
# 4      330897    565930      POST                            POSTAGE
#
#    Quantity  UnitPrice  CustomerID         Country        Date  Hour
# 0         1       3.25     15453.0  United Kingdom  2011-11-04    12
# 1        12       7.45     13098.0  United Kingdom  2011-10-10    10
# 2        12       3.75     16609.0  United Kingdom  2011-09-13     9
# 3        10       1.65     14329.0  United Kingdom  2011-01-14    13
# 4         5      18.00     12685.0          France  2011-09-08    10

# %%
df2= pd.read_csv('US_Holiday_Dates_(2004-2021).csv')
df2.head()
# Out:
#          Date      Holiday    WeekDay  Month  Day  Year
# 0  2004-07-04  4th of July     Sunday      7    4  2004
# 1  2005-07-04  4th of July     Monday      7    4  2005
# 2  2006-07-04  4th of July    Tuesday      7    4  2006
# 3  2007-07-04  4th of July  Wednesday      7    4  2007
# 4  2008-07-04  4th of July     Friday      7    4  2008

# %%
df=pd.concat([df1, df2], axis=1)
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                        Description  \
# 0      439570    574477     22591  CARDHOLDER GINGHAM CHRISTMAS TREE
# 1      387281    570275     23541         WALL ART CLASSIC PUDDINGS
# 2      337863    566482     22508           DOORSTOP RETROSPOT HEART
# 3       57628    541215     22662        LUNCH BAG DOLLY GIRL DESIGN
# 4      330897    565930      POST                            POSTAGE
#
#    Quantity  UnitPrice  CustomerID         Country        Date  Hour  \
# 0         1       3.25     15453.0  United Kingdom  2011-11-04    12
# 1        12       7.45     13098.0  United Kingdom  2011-10-10    10
# 2        12       3.75     16609.0  United Kingdom  2011-09-13     9
# 3        10       1.65     14329.0  United Kingdom  2011-01-14    13
# 4         5      18.00     12685.0          France  2011-09-08    10
#
#          Date      Holiday    WeekDay  Month  Day    Year
# 0  2004-07-04  4th of July     Sunday    7.0  4.0  2004.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81601 entries, 0 to 81600
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   81601 non-null  int64
#  1   InvoiceNo    81601 non-null  object
#  2   StockCode    81601 non-null  object
#  3   Description  81601 non-null  object
#  4   Quantity     81601 non-null  int64
#  5   UnitPrice    81601 non-null  float64
#  6   CustomerID   81601 non-null  float64
#  7   Country      81601 non-null  object
#  8   Date         81601 non-null  object
#  9   Hour         81601 non-null  int64
#  10  Date         342 non-null    object
#  11  Holiday      342 non-null    object
#  12  WeekDay      342 non-null    object
#  13  Month        342 non-null    float64
#  14  Day          342 non-null    float64
#  15  Year         342 non-null    float64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 10.0+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# InvoiceNo          0
# StockCode          0
# Description        0
# Quantity           0
# UnitPrice          0
# CustomerID         0
# Country            0
# Date               0
# Hour               0
# Date           81259
# Holiday        81259
# WeekDay        81259
# Month          81259
# Day            81259
# Year           81259
# dtype: int64

# %%
df.describe().round()
# Out:
#        Unnamed: 0  Quantity  UnitPrice  CustomerID     Hour  Month    Day  \
# count     81601.0   81601.0    81601.0     81601.0  81601.0  342.0  342.0
# mean     278271.0      12.0        3.0     15284.0     13.0    7.0   16.0
# std      152483.0      46.0       19.0      1713.0      2.0    4.0   10.0
# min           2.0   -3114.0        0.0     12347.0      6.0    1.0    1.0
# 25%      148283.0       2.0        1.0     13949.0     11.0    4.0    6.0
# 50%      284742.0       5.0        2.0     15144.0     13.0    9.0   16.0
# 75%      409445.0      12.0        4.0     16790.0     14.0   11.0   24.0
# max      541908.0    3186.0     4288.0     18287.0     20.0   12.0   31.0
#
#          Year
# count   342.0
# mean   2012.0
# std       5.0
# min    2004.0
# 25%    2008.0
# 50%    2012.0
# 75%    2017.0
# max    2021.0

# %%
df.shape
# Out:
# (81601, 16)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'InvoiceNo', 'StockCode', 'Description', 'Quantity',
#        'UnitPrice', 'CustomerID', 'Country', 'Date', 'Hour', 'Date', 'Holiday',
#        'WeekDay', 'Month', 'Day', 'Year'],
#       dtype='object')

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
import seaborn as sns
df['Expenditure']=df.Quantity*df.UnitPrice
df["Expenditure"] = df["Expenditure"].astype("int")
df.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                        Description  \
# 0      439570    574477     22591  CARDHOLDER GINGHAM CHRISTMAS TREE
# 1      387281    570275     23541         WALL ART CLASSIC PUDDINGS
# 2      337863    566482     22508           DOORSTOP RETROSPOT HEART
# 3       57628    541215     22662        LUNCH BAG DOLLY GIRL DESIGN
# 4      330897    565930      POST                            POSTAGE
#
#    Quantity  UnitPrice  CustomerID         Country        Date  Hour  \
# 0         1       3.25     15453.0  United Kingdom  2011-11-04    12
# 1        12       7.45     13098.0  United Kingdom  2011-10-10    10
# 2        12       3.75     16609.0  United Kingdom  2011-09-13     9
# 3        10       1.65     14329.0  United Kingdom  2011-01-14    13
# 4         5      18.00     12685.0          France  2011-09-08    10
#
#          Date      Holiday    WeekDay  Month  Day    Year  Expenditure
# ...

# %%
sns.barplot(x=df['Expenditure'],y=df['Holiday'])
plt.xticks(rotation='vertical')
plt.show()
